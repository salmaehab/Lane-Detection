# %% [markdown]
# ### cloning yolov5 repo from github

# %%
# !git clone https://github.com/ultralytics/yolov5.git

# %% [markdown]
# ### install requirements

# %%
# %cd yolov5
# %pip install -qr requirements.txt

# %%
import time
start_time = time.time()

# %%
# !python "./yolov5/detect.py" --weights yolov5s.pt --img 640 --conf 0.25 --source "test.mp4"
# Out:
# detect: weights=['yolov5s.pt'], source=test.mp4, data=yolov5\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.1-201-g9a7f289 Python-3.9.7 torch-1.11.0+cpu CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# video 1/1 (1/913) C:\Users\leno\test.mp4: 384x640 1 car, Done. (0.332s)
# video 1/1 (2/913) C:\Users\leno\test.mp4: 384x640 1 car, Done. (0.343s)
# video 1/1 (3/913) C:\Users\leno\test.mp4: 384x640 1 car, Done. (0.341s)
# video 1/1 (4/913) C:\Users\leno\test.mp4: 384x640 1 car, Done. (0.337s)
# video 1/1 (5/913) C:\Users\leno\test.mp4: 384x640 1 car, Done. (0.323s)
# ...

# %% [markdown]
# ### using detect file and passing video path to it

# %%
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 882.383917093277 seconds ---

# %%
import cv2
import numpy as np
   
# Create a VideoCapture object and read from input file
cap = cv2.VideoCapture('C:/Users/leno/yolov5/runs/detect/exp5/test.mp4')
   
# Check if camera opened successfully
if (cap.isOpened()== False): 
  print("Error opening video  file")
   
# Read until video is completed
while(cap.isOpened()):
      
  # Capture frame-by-frame
  ret, frame = cap.read()
  if ret == True:
   
    # Display the resulting frame
    cv2.imshow('Frame', frame)
   
    # Press Q on keyboard to  exit
    if cv2.waitKey(25) & 0xFF == ord('e'):
      break
   
  # Break the loop
  else: 
    break
   
# When everything done, release 
# the video capture object
cap.release()
   
# Closes all the frames
cv2.destroyAllWindows()
